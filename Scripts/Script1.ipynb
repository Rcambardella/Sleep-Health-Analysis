# %%
# 🛌 Sleep Health & Lifestyle Analysis

## 1. 📘 Introduction
"""
This project analyzes how lifestyle and health factors affect sleep duration and quality.
Goals:
- Test hypotheses (e.g., stress and physical activity effects)
- Uncover hidden insights
"""

## 2. 🔬 Hypotheses
"""
H1: High stress levels lead to less sleep
H2: Low physical activity is associated with less sleep
H3: Sleep duration correlates with sleep quality
"""

## 3. 📥 Load and Explore Data

## 4. 🧹 Data Cleaning & Preprocessing
# Handle nulls, encode categories, convert datatypes

## 5. 📊 Exploratory Analysis
# Use seaborn/matplotlib for histograms, boxplots, heatmaps

## 6. 🔎 Hypothesis Testing
# Groupby analysis, t-tests (if applicable), correlation

## 7. 💡 Key Insights
"""
-
"""

## 8. 📈 Recommendations
"""
-
"""

## 9. 📂 Appendix
# Extra code or visualizations
# Out:
# '\n-\n'

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

# Build the full path to the dataset inside the /data folder
data_path = os.path.join(project_root, "data", "Sleep_health_and_lifestyle_dataset.csv")

# Load the dataset
dataset = pd.read_csv(data_path)
dataset
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
dataset.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
dataset.isnull().sum()
# 219 Individuals out of 374 said they do not have sleeping disorders
# Out:
# Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %%
dataset['Sleep Disorder'].fillna('None', inplace=True)
dataset
# Out:
# C:\Users\Frenzy\AppData\Local\Temp\ipykernel_15868\353736695.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Sleep Disorder'].fillna('None', inplace=True)
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# ...

# %%
print(dataset['Stress Level'].value_counts())
# Out:
# Stress Level
# 3    71
# 8    70
# 4    70
# 5    67
# 7    50
# 6    46
# Name: count, dtype: int64

# %%
stress_sleep = dataset.groupby('Stress Level')['Sleep Duration'].mean().sort_index()
stress_sleep
# Out:
# Stress Level
# 3    8.226761
# 4    7.030000
# 5    7.483582
# 6    7.454348
# 7    6.468000
# 8    6.050000
# Name: Sleep Duration, dtype: float64

# %%
sns.set(style='whitegrid')

plt.figure(figsize=(8,5))
sns.lineplot(x=stress_sleep.index, y=stress_sleep.values)

plt.title('Average Sleep Duration by Stress Level', fontsize=14)
plt.xlabel('Stress Level', fontsize=12)
plt.ylabel('Average Sleep Duration (hours)', fontsize=12)
plt.xticks(rotation=0)
plt.tight_layout()

visuals_path = os.path.join(project_root, "visuals", "sleep_by_stress.png")

plt.savefig(visuals_path, bbox_inches='tight', dpi=300)

plt.show()

# %%
activity_sleep = dataset.groupby('Physical Activity Level')['Sleep Duration'].mean().sort_index()
activity_sleep
# Out:
# Physical Activity Level
# 30    7.185294
# 32    5.800000
# 35    6.500000
# 40    6.533333
# 42    6.100000
# 45    6.532353
# 47    6.900000
# 50    6.625000
# 55    7.100000
# 60    7.191429
# 65    7.300000
# 70    7.633333
# 75    7.913433
# 80    8.000000
# 85    8.100000
# 90    6.959701
# Name: Sleep Duration, dtype: float64

# %%
sns.set(style='whitegrid')

plt.figure(figsize=(8,5))
sns.lineplot(x=activity_sleep.index, y=activity_sleep.values)

plt.title('Average Sleep Duration by Physical Activity Level', fontsize=14)
plt.xlabel('Physical Activity Level', fontsize=12)
plt.ylabel('Average Sleep Duration (hours)', fontsize=12)
plt.xticks(rotation=0)
plt.tight_layout()

visuals_path = os.path.join(project_root, "visuals", "sleep_by_activity.png")

plt.savefig(visuals_path, bbox_inches='tight', dpi=300)

plt.show()

# %%
quality_duration = dataset.groupby('Quality of Sleep')['Sleep Duration'].mean().sort_index()
quality_duration
# Out:
# Quality of Sleep
# 4    5.860000
# 5    6.500000
# 6    6.195238
# 7    7.140260
# 8    7.403670
# 9    8.243662
# Name: Sleep Duration, dtype: float64

# %%
sns.set(style='whitegrid')

plt.figure(figsize=(8,5))
sns.lineplot(x=quality_duration.index, y=quality_duration.values)

plt.title('Average Sleep Duration by Quality of Sleep', fontsize=14)
plt.xlabel('Quality of Sleep', fontsize=12)
plt.ylabel('Average Sleep Duration (hours)', fontsize=12)
plt.xticks(rotation=0)
plt.tight_layout()

visuals_path = os.path.join(project_root, "visuals", "sleep_by_quality.png")

plt.savefig(visuals_path, bbox_inches='tight', dpi=300)

plt.show()
